# %%
from os import listdir
import requests
from bs4 import BeautifulSoup
import pandas as pd
import json
from tqdm.notebook import tqdm
import time
import random

# %%
# Парсинг условий продажи

# url = 'https://www.tomsk.ru09.ru/realty?subaction=detail&id=4414402'
# test_soup = get_soup_by_url(url)

# for i in df.index[0:10]:
#     test_soup = get_soup_by_url(i)
#     if
#     print(test_soup.find('sup').parent.text)

# get_soup_by_url(df.index[0])
# requests.get(df.index[0])

# %%
def get_soup_by_url(url):
    
    html_ = requests.get(url).text
    soup = BeautifulSoup(html_, 'lxml')
    
    return soup

# %%
address = ['Томск, Ванцетти переулок 6 2']

# %%
for i in address:
    test = get_soup_by_url('https://yandex.ru/maps/67/tomsk/search/{0}%2C/?ll=84.988419%2C56.533635&sll=84.988423%2C56.461173&sspn=0.008219%2C0.007510&z=11'.format(i))
    print(i, '-', test.find('div', {'class':'clipboard__action-wrapper _inline'}).text)
    time.sleep(random.randint(1, 3))
# Out:
# Томск, Ванцетти переулок 6 2 - 56.495752, 84.946113

# %%
# Получаем номер последней страницы
def get_number_last_page():
    
    soup = get_soup_by_url('https://www.tomsk.ru09.ru/realty?type=1&otype=1&district[1]=on&district[2]=on&district[3]=on&district[4]=on&perpage=50&page=1')
    number_last_page = int(soup.find('td', {'class':'pager_pages'}).find_all('a')[4].text)
    
    return number_last_page

# %%
def find_district_field(keys):
    
    for i, j in enumerate(keys):
        if 'район' in j:
            break
    return i

# %%
def parse_apartment(url):
#     headers = {'User-Agent: Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.132 Safari/537.36'}
#     start_time = time.time()
    
    soup = get_soup_by_url(url)
    
    keys = [i.find('span').text.replace('\xa0','').lower() for i in soup.find_all('tr', {'class': 'realty_detail_attr'})]
    
    district_idx = find_district_field(keys)
    items = {'район': keys[district_idx]}
    
    keys = [j for i, j in enumerate(keys) if i not in (district_idx - 1, district_idx)]
    values = [i.text.replace('\xa0', ' ') for i in soup.find_all(class_='nowrap')]
    
    items.update(dict(zip(keys, values)))
    
    items['адрес'] = soup.find(class_='table_map_link').text.replace('\xa0', ' ')
    items['цена'] = int(soup.find('div', {'class': 'realty_detail_price inline'}).text.replace('\xa0','').replace('руб.',''))
    items['ид'] = int(soup.find('strong').text)
    items['дата добавления'] = soup.find(class_='realty_detail_date nobr').get('title')
    items['дата истечения'] = soup.find_all(class_='realty_detail_date')[4].get('title')
    
    return items

# %%
def get_urls_pages(start_page=1, end_page=None):
    
    url_base = 'https://www.tomsk.ru09.ru/realty?type=1&otype=1&district[1]=on&district[2]=on&district[3]=on&district[4]=on&perpage=50&page='
    
    end_page = end_page or get_number_last_page()
    pages_to_parse = range(start_page, end_page + 1)
    urls_pages = [url_base + str(i) for i in pages_to_parse]
        
    return urls_pages

# %%
def get_urls_apartments_by_page(url_page):
    
    url_base = 'https://www.tomsk.ru09.ru'
    
    soup = get_soup_by_url(url_page)
    soup = soup.find_all('a', {'class':'visited_ads'})

    urls_apartments = set()
    
    for i in soup:
        urls_apartments.add(url_base + i.get('href'))
    
    return urls_apartments

# %%
def main(start_page=1, end_page=None, filename='data.json'):
    
    path = 'C:/Users/qwerty.Oleg/Desktop/MyProject/Data/'
    full_filename = path + filename
    
    if filename in listdir(path):
        with open(full_filename, 'r') as file:
            storage_dict = json.load(file)
    else:
        storage_dict = {}
    
    len_storage = len(storage_dict)
    print('Apartments in storage:', len_storage, '\n')
    
    urls_pages = get_urls_pages(start_page, end_page)
    
    for url_page in tqdm(urls_pages, desc='Pages'):
        urls_apartments = get_urls_apartments_by_page(url_page)
        urls_apartments_to_parse = urls_apartments.difference(set(storage_dict))
        
        if len(urls_apartments_to_parse) != 0:
            for url_apartment in tqdm(urls_apartments_to_parse, desc='Apartments', leave=False):
                storage_dict[url_apartment] = parse_apartment(url_apartment)
        
    with open(full_filename, 'w') as file:
        json.dump(storage_dict, file, ensure_ascii=False)
            
    print('New apartments:', len(storage_dict) - len_storage)

# %%
main()
# Out:
# Apartments in storage: 7325
# HBox(children=(FloatProgress(value=0.0, description='Pages', max=1.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='Apartments', max=20.0, style=ProgressStyle(description_wi…
# New apartments: 20

# %%
with open('C:/Users/qwerty.Oleg/Desktop/MyProject/Data/data.json', 'r') as file:
    dict_data = json.load(file)
pd.DataFrame.from_dict(dict_data, orient='index')
# Out:
#                                                               район  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...  кировский район
# https://www.tomsk.ru09.ru/realty?subaction=deta...  кировский район
# https://www.tomsk.ru09.ru/realty?subaction=deta...  кировский район
# https://www.tomsk.ru09.ru/realty?subaction=deta...  советский район
# https://www.tomsk.ru09.ru/realty?subaction=deta...  ленинский район
# ...                                                             ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...  кировский район
# https://www.tomsk.ru09.ru/realty?subaction=deta...  советский район
# https://www.tomsk.ru09.ru/realty?subaction=deta...  ленинский район
# https://www.tomsk.ru09.ru/realty?subaction=deta...  ленинский район
# https://www.tomsk.ru09.ru/realty?subaction=deta...  ленинский район
#
#                                                    количество комнат  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 2
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 2
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 2
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 2
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 3
# ...                                                              ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 3
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 1
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 1
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 2
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 1
#
#                                                    общая площадь  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...       60 кв.м
# https://www.tomsk.ru09.ru/realty?subaction=deta...    57.45 кв.м
# https://www.tomsk.ru09.ru/realty?subaction=deta...     43.6 кв.м
# https://www.tomsk.ru09.ru/realty?subaction=deta...     67.8 кв.м
# https://www.tomsk.ru09.ru/realty?subaction=deta...     64.8 кв.м
# ...                                                          ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...     60.2 кв.м
# https://www.tomsk.ru09.ru/realty?subaction=deta...       35 кв.м
# https://www.tomsk.ru09.ru/realty?subaction=deta...     22.5 кв.м
# https://www.tomsk.ru09.ru/realty?subaction=deta...       45 кв.м
# https://www.tomsk.ru09.ru/realty?subaction=deta...       26 кв.м
#
#                                                    этаж/этажность  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...            1/2
# https://www.tomsk.ru09.ru/realty?subaction=deta...           2/10
# https://www.tomsk.ru09.ru/realty?subaction=deta...            5/5
# https://www.tomsk.ru09.ru/realty?subaction=deta...            1/9
# https://www.tomsk.ru09.ru/realty?subaction=deta...            3/9
# ...                                                           ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...            5/5
# https://www.tomsk.ru09.ru/realty?subaction=deta...           8/18
# https://www.tomsk.ru09.ru/realty?subaction=deta...            5/5
# https://www.tomsk.ru09.ru/realty?subaction=deta...            3/5
# https://www.tomsk.ru09.ru/realty?subaction=deta...            2/2
#
#                                                                  отделка  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...   в хорошем состоянии
# https://www.tomsk.ru09.ru/realty?subaction=deta...   в хорошем состоянии
# https://www.tomsk.ru09.ru/realty?subaction=deta...  в отличном состоянии
# https://www.tomsk.ru09.ru/realty?subaction=deta...                   NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...   в хорошем состоянии
# ...                                                                  ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...   в хорошем состоянии
# https://www.tomsk.ru09.ru/realty?subaction=deta...                   NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...   в хорошем состоянии
# https://www.tomsk.ru09.ru/realty?subaction=deta...  в отличном состоянии
# https://www.tomsk.ru09.ru/realty?subaction=deta...      требуется ремонт
#
#                                                         санузел этажность  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...  совмещенный         2
# https://www.tomsk.ru09.ru/realty?subaction=deta...   раздельный        10
# https://www.tomsk.ru09.ru/realty?subaction=deta...  совмещенный         5
# https://www.tomsk.ru09.ru/realty?subaction=deta...          NaN         9
# https://www.tomsk.ru09.ru/realty?subaction=deta...   раздельный         9
# ...                                                         ...       ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...   раздельный         5
# https://www.tomsk.ru09.ru/realty?subaction=deta...  совмещенный        18
# https://www.tomsk.ru09.ru/realty?subaction=deta...  совмещенный         5
# https://www.tomsk.ru09.ru/realty?subaction=deta...          NaN         5
# https://www.tomsk.ru09.ru/realty?subaction=deta...  совмещенный         2
#
#                                                    материал        вид  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...   дерево  вторичное
# https://www.tomsk.ru09.ru/realty?subaction=deta...   панель  вторичное
# https://www.tomsk.ru09.ru/realty?subaction=deta...   кирпич  вторичное
# https://www.tomsk.ru09.ru/realty?subaction=deta...   кирпич  вторичное
# https://www.tomsk.ru09.ru/realty?subaction=deta...   панель  вторичное
# ...                                                     ...        ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...   панель  вторичное
# https://www.tomsk.ru09.ru/realty?subaction=deta...  монолит  вторичное
# https://www.tomsk.ru09.ru/realty?subaction=deta...   кирпич  вторичное
# https://www.tomsk.ru09.ru/realty?subaction=deta...   кирпич  вторичное
# https://www.tomsk.ru09.ru/realty?subaction=deta...   дерево  вторичное
#
#                                                                           адрес  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...  Ленина (село Тимирязевское)
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 Мокрушина 13
# https://www.tomsk.ru09.ru/realty?subaction=deta...           Полины Осипенко 8а
# https://www.tomsk.ru09.ru/realty?subaction=deta...                Сибирская 118
# https://www.tomsk.ru09.ru/realty?subaction=deta...           Ференца Мюнниха 22
# ...                                                                         ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...  пос. Лоскутово, Гагарина 47
# https://www.tomsk.ru09.ru/realty?subaction=deta...            Сергея Вицмана 37
# https://www.tomsk.ru09.ru/realty?subaction=deta...      Заозерный переулок 16/2
# https://www.tomsk.ru09.ru/realty?subaction=deta...           Красный переулок 7
# https://www.tomsk.ru09.ru/realty?subaction=deta...         Целинный переулок 28
#
#                                                        цена       ид  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...  1490000  4417386
# https://www.tomsk.ru09.ru/realty?subaction=deta...  3150000  4346012
# https://www.tomsk.ru09.ru/realty?subaction=deta...  3150000  4433464
# https://www.tomsk.ru09.ru/realty?subaction=deta...  3280000  4255446
# https://www.tomsk.ru09.ru/realty?subaction=deta...  3550000  4424538
# ...                                                     ...      ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...  2900000  4434228
# https://www.tomsk.ru09.ru/realty?subaction=deta...  1700000  4434196
# https://www.tomsk.ru09.ru/realty?subaction=deta...  1350000  4434198
# https://www.tomsk.ru09.ru/realty?subaction=deta...  3450000  4388244
# https://www.tomsk.ru09.ru/realty?subaction=deta...   740000  4434224
#
#                                                         дата добавления  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...  01.05.2020 13:03:25
# https://www.tomsk.ru09.ru/realty?subaction=deta...  29.04.2020 13:36:07
# https://www.tomsk.ru09.ru/realty?subaction=deta...  01.05.2020 13:04:34
# https://www.tomsk.ru09.ru/realty?subaction=deta...  01.05.2020 13:06:14
# https://www.tomsk.ru09.ru/realty?subaction=deta...  01.05.2020 13:07:06
# ...                                                                 ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...  03.05.2020 16:21:03
# https://www.tomsk.ru09.ru/realty?subaction=deta...  03.05.2020 14:55:47
# https://www.tomsk.ru09.ru/realty?subaction=deta...  03.05.2020 14:56:39
# https://www.tomsk.ru09.ru/realty?subaction=deta...  03.05.2020 13:55:04
# https://www.tomsk.ru09.ru/realty?subaction=deta...  03.05.2020 15:38:19
#
#                                                    дата истечения     кухня  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...     30.07.2020       NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...     28.07.2020   10 кв.м
# https://www.tomsk.ru09.ru/realty?subaction=deta...     30.07.2020  4.7 кв.м
# https://www.tomsk.ru09.ru/realty?subaction=deta...     15.06.2020       NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...     30.07.2020       NaN
# ...                                                           ...       ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...     17.06.2020       NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...     17.06.2020       NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...           None       NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...     01.08.2020       NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...     01.08.2020       NaN
#
#                                                          балкон/лоджия  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...  балкон, остекление
# https://www.tomsk.ru09.ru/realty?subaction=deta...  балкон, остекление
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...  лоджия, остекление
# ...                                                                ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...  балкон, остекление
# https://www.tomsk.ru09.ru/realty?subaction=deta...  лоджия, остекление
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...  балкон, остекление
# https://www.tomsk.ru09.ru/realty?subaction=deta...                 NaN
#
#                                                    год постройки    жилая  \
# https://www.tomsk.ru09.ru/realty?subaction=deta...           NaN      NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...          2002      NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...          1963  32 кв.м
# https://www.tomsk.ru09.ru/realty?subaction=deta...          2008  50 кв.м
# https://www.tomsk.ru09.ru/realty?subaction=deta...          1978      NaN
# ...                                                          ...      ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...           NaN      NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...          2018      NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...          1972      NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...          1967      NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...           NaN      NaN
#
#                                                       тип квартиры
# https://www.tomsk.ru09.ru/realty?subaction=deta...             NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...             NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...             NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...             NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...             NaN
# ...                                                            ...
# https://www.tomsk.ru09.ru/realty?subaction=deta...             NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...             NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...  малогабаритная
# https://www.tomsk.ru09.ru/realty?subaction=deta...             NaN
# https://www.tomsk.ru09.ru/realty?subaction=deta...             NaN
#
# [7345 rows x 19 columns]
